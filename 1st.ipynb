# %%
# %tensorflow_version 2.x
# Out:
# TensorFlow 2.x selected.

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
# %cd drive/My Drive/AniRe
# Out:
# /content/drive/My Drive/AniRe

# %%
from keras import models
from keras.models import Sequential
from keras.utils import plot_model, np_utils
from keras.preprocessing import image
from keras import layers
from keras.preprocessing.image import ImageDataGenerator
from keras.optimizers import SGD, RMSprop,Adam
from keras.applications.vgg16 import VGG16
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib.image as npimg
import os, signal
from keras.layers import Dense, Conv2D, MaxPooling2D, Dropout, GlobalAveragePooling2D, Flatten

# %%
# !unzip animals10.zip

# %% [markdown]
# 1. phân tích dữ liệu

# %%
import shutil

# %%
import shutil
data_raw = '/content/drive/My Drive/AniRe/animals/raw-img'
base_dir='/content/drive/My Drive/AniRe'
lst_class = os.listdir(data_raw)


train_dir = os.path.join(base_dir, 'train')
test_dir = os.path.join(base_dir, 'test')
frame = {}
for class_animal in lst_class:
    temp = os.path.join(data_raw, class_animal)
    frame[class_animal] = os.listdir(temp)

    try:
        os.mkdir(train_dir +"/"+ class_animal)
    except:
        print('Cannot created train dir')

    try:
        os.mkdir(test_dir +"/"+ class_animal)
    except:
        print('Cannot created validation dir')
# Out:
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir
# Cannot created train dir
# Cannot created validation dir

# %%
for animal_class in lst_class:
    rawfile_dir = os.path.join(rawdata_dir, animal_class)
    train = int(len(frame[animal_class])*0.8)
    tem = os.path.join(train_dir, animal_class)
    for x in frame[animal_class][:train]:
        cur_dir = os.path.join(rawfile_dir, x)
        shutil.move(cur_dir, tem)
    tem = os.path.join(val_dir, animal_class)
    for x in frame[animal_class][train:]:
        cur_dir = os.path.join(rawfile_dir, x)
        shutil.move(cur_dir, tem)

# %%
flower = 'cane'
tem = os.path.join(train_dir, flower)
print(flower, len(os.listdir(tem)))

tem = os.path.join(val_dir, flower)
print(flower, len(os.listdir(tem)))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-55209badf65f> in <module>()
#       1 flower = 'cane'
#       2 tem = os.path.join(train_dir, flower)
# ----> 3 print(flower, len(os.listdir(tem)))
#       4
#       5 tem = os.path.join(val_dir, flower)
#
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/My Drive/AniRe/train/cane'

# %% [markdown]
# 2. tiền xử lý

# %%
base_dir = '/content/drive/My Drive/AniRe/animals'
train_dir=os.path.join(base_dir,'train')
validation_dir=os.path.join(base_dir,'test')
train_datagen = ImageDataGenerator(
        rescale=1./255,
        shear_range=0.2,
        zoom_range=0.2,
        horizontal_flip=True)

test_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_directory(
        train_dir,
        target_size=(224, 224),
        batch_size=128,
        class_mode='categorical')

validation_generator = test_datagen.flow_from_directory(
         validation_dir,
        target_size=(224, 224),
        batch_size=128,
        class_mode='categorical')
# Out:
# Found 22608 images belonging to 10 classes.
# Found 5658 images belonging to 10 classes.

# %%
pre_trained_model = VGG16(input_shape = (224, 224, 3))

# %%
for layer in pre_trained_model.layers:
  layer.trainable=True

# %%
pre_trained_model.summary()
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_2 (InputLayer)         (None, 224, 224, 3)       0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
model = models.Sequential()

model.add(pre_trained_model)
model.add(Flatten())
model.add(Dense(512, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(10, activation='softmax'))
model.summary()
model.compile(optimizer=optimizers.adam(lr=learning_rate), loss='categorical_crossentropy', metrics=['accuracy'])
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-46-85c4445a8f7a> in <module>()
#       2
#       3 model.add(pre_trained_model)
# ----> 4 model.add(Flatten())
#       5 model.add(Dense(512, activation='relu'))
#       6 model.add(Dropout(0.5))
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/sequential.py in add(self, layer)
#     180                 self.inputs = network.get_source_inputs(self.outputs[0])
#     181         elif self.outputs:
# --> 182             output_tensor = layer(self.outputs[0])
#     183             if isinstance(output_tensor, list):
#     184                 raise TypeError('All layers in a Sequential model '
#
# /usr/local/lib/python3.6/dist-packages/keras/engine/base_layer.py in __call__(self, inputs, **kwargs)
#     406                 # Raise exceptions in case the input is not compatible
# ...

# %%
history=model.fit_generator(
        train_generator,
        steps_per_epoch=len(train_generator)/128,
        epochs=50,
        validation_data=validation_generator,
        validation_steps=800)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-31212b437609> in <module>()
#       2
#       3 history=Model.fit_generator(
# ----> 4         train_generator,
#       5         steps_per_epoch=len(train_generator)/128,
#       6         epochs=50,
#
# NameError: name 'train_generator' is not defined

# %% [markdown]
# # New Section
